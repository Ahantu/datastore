# %%
import geopandas

# %%
gdf = geopandas.read_file("./rwa_district/District.shp")

# %%
gdf.head(20)
# Out:
#     Dist_ID    District                                           geometry
# 0      11.0  Nyarugenge  POLYGON ((498847.140 4793516.119, 498839.366 4...
# 1      12.0      Gasabo  POLYGON ((516449.907 4801793.262, 516466.827 4...
# 2      13.0    Kicukiro  POLYGON ((515970.104 4783945.205, 516021.558 4...
# 3      21.0      Nyanza  POLYGON ((494532.396 4753088.125, 494601.047 4...
# 4      22.0    Gisagara  POLYGON ((495061.551 4734993.648, 495089.120 4...
# 5      23.0   Nyaruguru  POLYGON ((448896.974 4719940.434, 448893.131 4...
# 6      24.0        Huye  POLYGON ((476906.123 4737884.445, 476928.796 4...
# 7      25.0   Nyamagabe  POLYGON ((450828.758 4756737.440, 450843.405 4...
# 8      26.0     Ruhango  POLYGON ((487315.406 4767720.183, 487327.382 4...
# 9      27.0     Muhanga  POLYGON ((463074.713 4808591.618, 463100.182 4...
# 10     28.0     Kamonyi  POLYGON ((479691.474 4795134.441, 479717.739 4...
# ...

# %%
gdf = gdf.to_crs('EPSG:4326')

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.to_file('districts.geojson', driver="GeoJSON")

# %%
valid_geo = geopandas.read_file("./districts.geojson",)

# %%
valid_geo.head(100)
# Out:
#     Dist_ID    District                                           geometry
# 0      11.0  Nyarugenge  POLYGON ((29.98964 -1.86756, 29.98957 -1.86789...
# 1      12.0      Gasabo  POLYGON ((30.14786 -1.79269, 30.14801 -1.79270...
# 2      13.0    Kicukiro  POLYGON ((30.14356 -1.95412, 30.14402 -1.95429...
# 3      21.0      Nyanza  POLYGON ((29.95084 -2.23321, 29.95146 -2.23339...
# 4      22.0    Gisagara  POLYGON ((29.95559 -2.39686, 29.95584 -2.39749...
# 5      23.0   Nyaruguru  POLYGON ((29.54045 -2.53293, 29.54041 -2.53316...
# 6      24.0        Huye  POLYGON ((29.79235 -2.37070, 29.79255 -2.37085...
# 7      25.0   Nyamagabe  POLYGON ((29.55792 -2.20014, 29.55806 -2.20021...
# 8      26.0     Ruhango  POLYGON ((29.88596 -2.10086, 29.88607 -2.10100...
# 9      27.0     Muhanga  POLYGON ((29.66811 -1.73118, 29.66834 -1.73122...
# 10     28.0     Kamonyi  POLYGON ((29.81745 -1.85291, 29.81769 -1.85307...
# ...
