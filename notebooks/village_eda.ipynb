# %%
import geopandas

# %%
gdf = geopandas.read_file("./rwa_villages/Village.shp")

# %%
gdf.head(20)
# Out:
#       District Village_ID Cell_ID Sector_ID Distr_ID Prov_ID         Name  \
# 0   Nyarugenge   11010102  110101      1101       11       1      Gihanga
# 1   Nyarugenge   11010103  110101      1101       11       1   Iterambere
# 2   Nyarugenge   11010104  110101      1101       11       1        Izuba
# 3   Nyarugenge   11010105  110101      1101       11       1   Nyaburanga
# 4   Nyarugenge   11010106  110101      1101       11       1     Nyenyeri
# 5   Nyarugenge   11010107  110101      1101       11       1  Ubukorikori
# 6   Nyarugenge   11010108  110101      1101       11       1       Ubumwe
# 7   Nyarugenge   11010109  110101      1101       11       1    Ubwiyunge
# 8   Nyarugenge   11010110  110101      1101       11       1       Umucyo
# 9   Nyarugenge   11010111  110101      1101       11       1     Umurabyo
# 10  Nyarugenge   11010112  110101      1101       11       1      Umuseke
# 11  Nyarugenge   11010113  110101      1101       11       1       Vugizo
# ...

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf = gdf.to_crs('EPSG:4326')

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.to_file('villages.geojson', driver="GeoJSON")

# %%
valid_geo = geopandas.read_file("./villages.geojson",)

# %%
valid_geo.head(100)
# Out:
#       District Village_ID Cell_ID Sector_ID Distr_ID Prov_ID        Name  \
# 0   Nyarugenge   11010102  110101      1101       11       1     Gihanga
# 1   Nyarugenge   11010103  110101      1101       11       1  Iterambere
# 2   Nyarugenge   11010104  110101      1101       11       1       Izuba
# 3   Nyarugenge   11010105  110101      1101       11       1  Nyaburanga
# 4   Nyarugenge   11010106  110101      1101       11       1    Nyenyeri
# ..         ...        ...     ...       ...      ...     ...         ...
# 95  Nyarugenge   11030304  110303      1103       11       1    Kadobogo
# 96  Nyarugenge   11030305  110303      1103       11       1     Kamenge
# 97  Nyarugenge   11030306  110303      1103       11       1      Karama
# 98  Nyarugenge   11030307  110303      1103       11       1    Kiruhura
# 99  Nyarugenge   11030308  110303      1103       11       1   Nyabikoni
#
#          Cell  Sector                      Province  \
# ...
