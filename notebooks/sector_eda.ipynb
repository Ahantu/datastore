# %%
import geopandas

# %%
gdf = geopandas.read_file("./rwa_sector/Sector.shp")

# %%
gdf.crs
# Out:
# <Projected CRS: PROJCS["TM_Rwanda",GEOGCS["ITRF2005",DATUM["Intern ...>
# Name: TM_Rwanda
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: International Terrestrial Reference Frame 2005
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.head(20)
# Out:
#     Prov_ID     Province  Dist_ID    District  Sect_ID        Name  \
# 0       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega
# 1       1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya
# 2       1.0  Kigali City     11.0  Nyarugenge   1103.0      Kigali
# 3       1.0  Kigali City     11.0  Nyarugenge   1104.0  Kimisagara
# 4       1.0  Kigali City     11.0  Nyarugenge   1105.0  Mageregere
# 5       1.0  Kigali City     11.0  Nyarugenge   1106.0      Muhima
# 6       1.0  Kigali City     11.0  Nyarugenge   1107.0  Nyakabanda
# 7       1.0  Kigali City     11.0  Nyarugenge   1108.0  Nyamirambo
# 8       1.0  Kigali City     11.0  Nyarugenge   1109.0  Nyarugenge
# 9       1.0  Kigali City     11.0  Nyarugenge   1110.0  Rwezamenyo
# 10      1.0  Kigali City     12.0      Gasabo   1201.0     Bumbogo
# 11      1.0  Kigali City     12.0      Gasabo   1202.0     Gatsata
# 12      1.0  Kigali City     12.0      Gasabo   1203.0    Gikomero
# ...

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf = gdf.to_crs('EPSG:4326')

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.head()
# Out:
#    Prov_ID     Province  Dist_ID    District  Sect_ID        Name  \
# 0      1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega
# 1      1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya
# 2      1.0  Kigali City     11.0  Nyarugenge   1103.0      Kigali
# 3      1.0  Kigali City     11.0  Nyarugenge   1104.0  Kimisagara
# 4      1.0  Kigali City     11.0  Nyarugenge   1105.0  Mageregere
#
#                                             geometry
# 0  POLYGON ((30.04829 -1.94176, 30.04833 -1.94178...
# 1  POLYGON ((29.98964 -1.86756, 29.98957 -1.86789...
# 2  POLYGON ((30.04030 -1.94181, 30.04036 -1.94183...
# 3  POLYGON ((30.04496 -1.93947, 30.04501 -1.93955...
# 4  POLYGON ((30.05227 -2.00171, 30.05232 -2.00175...

# %%
gdf.to_file('sectors.geojson', driver="GeoJSON")

# %%
valid_geo = geopandas.read_file("./sectors.geojson",)

# %%
valid_geo.head(100)
# Out:
#     Prov_ID           Province  Dist_ID    District  Sect_ID        Name  \
# 0       1.0        Kigali City     11.0  Nyarugenge   1101.0      Gitega
# 1       1.0        Kigali City     11.0  Nyarugenge   1102.0    Kanyinya
# 2       1.0        Kigali City     11.0  Nyarugenge   1103.0      Kigali
# 3       1.0        Kigali City     11.0  Nyarugenge   1104.0  Kimisagara
# 4       1.0        Kigali City     11.0  Nyarugenge   1105.0  Mageregere
# ..      ...                ...      ...         ...      ...         ...
# 95      2.0  Southern Province     25.0   Nyamagabe   2510.0       Mbazi
# 96      2.0  Southern Province     25.0   Nyamagabe   2511.0      Mugano
# 97      2.0  Southern Province     25.0   Nyamagabe   2512.0     Musange
# 98      2.0  Southern Province     25.0   Nyamagabe   2513.0    Musebeya
# 99      2.0  Southern Province     25.0   Nyamagabe   2514.0     Mushubi
#
#                                              geometry
# ...
