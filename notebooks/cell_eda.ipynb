# %%
import geopandas
from shapely.geometry import Point, Polygon

# %%
gdf = geopandas.read_file("./Rwanda_Cells/Cell.shp")

# %%
gdf.head(20)
# Out:
#     Prov_ID     Province  Dist_ID    District  Sect_ID      Sector   Cell_ID  \
# 0       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110101.0
# 1       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110102.0
# 2       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110103.0
# 3       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110104.0
# 4       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110105.0
# 5       1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega  110106.0
# 6       1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya  110201.0
# 7       1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya  110202.0
# 8       1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya  110203.0
# 9       1.0  Kigali City     11.0  Nyarugenge   1103.0      Kigali  110301.0
# 10      1.0  Kigali City     11.0  Nyarugenge   1103.0      Kigali  110302.0
# ...

# %%
gdf.crs
# Out:
# <Projected CRS: PROJCS["TM_Rwanda",GEOGCS["ITRF2005",DATUM["Intern ...>
# Name: TM_Rwanda
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: International Terrestrial Reference Frame 2005
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf = gdf.to_crs('EPSG:4326')

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.to_file("cells.geojson", driver="GeoJSON")

# %%
geo_village = geopandas.read_file("./cells.geojson",)

# %%
geo_village.head(100)
# Out:
#     Prov_ID     Province  Dist_ID    District  Sect_ID  Sector   Cell_ID  \
# 0       1.0  Kigali City     11.0  Nyarugenge   1101.0  Gitega  110101.0
# 1       1.0  Kigali City     11.0  Nyarugenge   1101.0  Gitega  110102.0
# 2       1.0  Kigali City     11.0  Nyarugenge   1101.0  Gitega  110103.0
# 3       1.0  Kigali City     11.0  Nyarugenge   1101.0  Gitega  110104.0
# 4       1.0  Kigali City     11.0  Nyarugenge   1101.0  Gitega  110105.0
# ..      ...          ...      ...         ...      ...     ...       ...
# 95      1.0  Kigali City     12.0      Gasabo   1212.0   Nduba  121202.0
# 96      1.0  Kigali City     12.0      Gasabo   1212.0   Nduba  121203.0
# 97      1.0  Kigali City     12.0      Gasabo   1212.0   Nduba  121204.0
# 98      1.0  Kigali City     12.0      Gasabo   1212.0   Nduba  121205.0
# 99      1.0  Kigali City     12.0      Gasabo   1212.0   Nduba  121206.0
#
#          Name                                           geometry
# ...

# %%
geo_village.count()
# Out:
# Prov_ID     2148
# Province    2148
# Dist_ID     2148
# District    2148
# Sect_ID     2148
# Sector      2148
# Cell_ID     2148
# Name        2148
# geometry    2148
# dtype: int64

# %%
grouped = geo_village.groupby('Province')
